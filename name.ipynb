# %%
import random as r
a1 = ['赵', '钱', '孙', '李', '周', '吴', '郑', '王', '冯', '陈', '褚', '蒋', '沈', '韩', '杨', '朱', '秦', '尤', '许',
      '何', '吕', '施', '张', '孔', '曹', '严', '华', '金', '魏', '陶', '姜', '戚', '谢', '邹', '窦', '章',
                 '苏', '潘', '葛',  '范', '彭', '鲁', '韦', '马', '苗', '方', '俞', '任', '袁', '柳',
                  '鲍', '史', '唐', '费', '廉',  '薛', '雷', '贺', '倪', '汤', '滕', '殷', '罗', '毕', '郝', '邬', '安', '常',
                  '乐', '于', '时', '傅', '齐', '康', '伍', '余', '顾', '孟', '平', '黄', '穆', '萧', '尹',
                  '姚', '邵', '汪', '祁', '毛', '禹', '狄', '伏', '成', '戴', '谈', '宋', '茅', '庞',
                  '熊', '纪', '舒', '屈', '项', '祝', '董', '梁']

a2 = ['玉','明','龙','芳','','军','','立','','平','','洪','','天','','少','强','','勇','','伟','','卫','','正','','明','','义','云','','远','','元','','佳','','廷','桐','','小',
      '大','春','明','']


a3 = ['立','玲','国', '家','天', '能','多', '然', '心', '学', '之', '都', '顺', '秋','凡',
                '雄', '升',  '典', '盛', '济', '蒙', '棋', '龙','君','俊'
                   ,'乾', '坤']



print(len(a1)*len(a2) //2 *len(a3))
# Out:
# 61412
